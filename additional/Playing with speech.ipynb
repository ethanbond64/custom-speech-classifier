# %% [markdown]
# # A Notebook For Playing With Speeches

# %% [markdown]
# ### Using a personal text class -- turns a corpus into a tokenized matrix for reading

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(threshold=np.inf,linewidth=150)

# %%
from SpeechTextClass import speechText

# %% [markdown]
# #### Takes a text file as input. The text file must contain all of the writing on a single continuous line to avoid \n chars FIXME soon

# %% [markdown]
# #### Class Details
#  - Attributes include tokens, vectors, syllables
#  - Functions include findSimilar

# %%
steve = speechText('SteveJobsSnippet.txt')

# %%
print(steve.syllables.sum(axis=1).transpose())
plt.plot(steve.syllables.sum(axis=1))
plt.show()
# Out:
# [[33. 16.  2. 21. 11. 31.  7. 11. 14. 10. 13. 10. 22. 16. 18. 10. 28. 30.  7. 10. 11. 10. 12. 17.  5.  3.  3. 48. 10. 11. 16.  6. 32.  5. 17. 12.
#    9.  7. 17.  7. 11.  6.  9. 15.  8.  5.  6. 11. 22. 17.  5. 13. 16. 10.  4. 18. 13. 21. 11.  6. 14. 10.  9. 11.  8.  6. 12. 19.  8.  7.  4.  5.
#   24. 19.  9.  3. 13.  3.  3. 11.  2.  9.  5.  3.  3.  6.]]

# %%
# plt.plot(steve.syllables)
# fig = plt.figure()
# ax = fig.add_subplot(1,1,1)
# ax.set_aspect('equal')
plt.imshow(steve.syllables, interpolation='nearest', cmap=plt.cm.ocean)
plt.colorbar()
plt.show()
